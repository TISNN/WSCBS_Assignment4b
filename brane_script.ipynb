# %%
import init;
# Out:
# Package 'init' imports function 'init', but that global variable already exists

# %%
init("init");

# %%
import getfeatures;

# %%
processing("EDA");
processing("train");
processing("test");

# %%
import train_predict;

# %%
train_predict("knn");
train_predict("decision_tree");

# %%
import visual;

# %%
gender("EDA");

# %%
print("file:///data/gender_EDA.png");

# %%
pclass("EDA");

# %%
print("file:///data/pclass_EDA.png");

# %%
Ticket("EDA");

# %%
print("file:///data/Ticket_EDA.png");

# %%
Title("EDA");

# %%
print("file:///data/Title_EDA.png");

# %%
Correlation("EDA");

# %%
print("file:///data/Correlation_EDA.png");
